# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayu-sshhhhh/Food-Vision-Classifier/blob/main/main_Food_Vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Dataset : Food101
# * Preprocessing func. for our data
# * Batching & prep of dataset for modelling
# * Set up mixed preciion training

# %% [markdown]
# ## Getting helper func.

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/refs/heads/main/extras/helper_functions.py
# Out:
# --2026-05-29 03:10:10--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/refs/heads/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2026-05-29 03:10:10 (110 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %% [markdown]
# ## Checking our GPU

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-2e51e5c0-8f85-f10f-2129-f8d0742d2a13)

# %% [markdown]
# We are using Tesla T4 GPU

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves, compare_historys

# %% [markdown]
# ## Using TensorFlow Datasets to download data

# %%
import tensorflow_datasets as tfds

# %%
(train_data, test_data), ds_info = tfds.load(name="food101",
                                             split=["train","validation"],
                                             shuffle_files= True,
                                             as_supervised = True,
                                             with_info= True)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/food101/2.0.0 has no dataset_info.json
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.70ISKT_2.0.0/food101-train.tfrecord-[0-9][0-9][0-9][0-9…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.70ISKT_2.0.0/food101-validation.tfrecord-[0-9][0-9][0-9…
# Dataset food101 downloaded and prepared to /root/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.

# %%
ds_info.features
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=uint8),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=101),
# })

# %%
class_names = ds_info.features["label"].names
class_names[:20]
# Out:
# ['apple_pie',
#  'baby_back_ribs',
#  'baklava',
#  'beef_carpaccio',
#  'beef_tartare',
#  'beet_salad',
#  'beignets',
#  'bibimbap',
#  'bread_pudding',
#  'breakfast_burrito',
#  'bruschetta',
#  'caesar_salad',
#  'cannoli',
#  'caprese_salad',
#  'carrot_cake',
#  'ceviche',
#  'cheesecake',
#  'cheese_plate',
#  'chicken_curry',
#  'chicken_quesadilla']

# %%
ds_info.splits
# Out:
# {Split('train'): <SplitInfo num_examples=75750, num_shards=32>,
#  Split('validation'): <SplitInfo num_examples=25250, num_shards=16>}
